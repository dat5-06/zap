# %%
import numpy as np
import matplotlib.pyplot as plt
from core.util.io import read_csv

# %%
norlys_cons_data = read_csv("interim/norlys_cons_interim.csv")

norlys_cons_data
# Out:
#             date  hour  kwh_percentage
# 0     2024-03-01     0        0.597495
# 1     2024-03-01     1        0.677872
# 2     2024-03-01     2        0.561087
# 3     2024-03-01     3        0.369979
# 4     2024-03-01     4        0.202515
# ...          ...   ...             ...
# 5874  2024-10-31    19        0.076742
# 5875  2024-10-31    20        0.086831
# 5876  2024-10-31    21        0.136549
# 5877  2024-10-31    22        0.192147
# 5878  2024-10-31    23        0.247977
#
# [5879 rows x 3 columns]

# %%
norlys_pub_interim = read_csv("interim/norlys_pub_interim.csv")

norlys_pub_interim
# Out:
#             date  hour  kwh_percentage
# 0     2024-03-01     0        0.043796
# 1     2024-03-01     1        0.093013
# 2     2024-03-01     2        0.006508
# 3     2024-03-01     3        0.011450
# 4     2024-03-01     4        0.031613
# ...          ...   ...             ...
# 5873  2024-10-31    19        0.182902
# 5874  2024-10-31    20        0.163774
# 5875  2024-10-31    21        0.169173
# 5876  2024-10-31    22        0.112087
# 5877  2024-10-31    23        0.098231
#
# [5878 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))

plt.ylabel("Mean consumption normalized (%)")
plt.xlabel("Hour of day")
plt.xticks(range(24))
plt.yticks(np.arange(0, 1, 0.1))
plt.grid(alpha=0.6)

ax = plt.gca()
ax.set_xlim([0, 23])
ax.set_ylim([0, 1])

plt.plot(norlys_cons_data["kwh_percentage"], "o--")

plt.show()
